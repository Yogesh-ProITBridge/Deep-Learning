# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd

# %%
df = pd.read_csv("/content/diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
x = df.drop('Outcome', axis=1)
y = df['Outcome']

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(x)
# Out:
# MinMaxScaler()

# %%
x_scaled = scaler.transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size = 0.2, random_state = 83)

# %%
pip install scikeras[tensorflow]
# Out:
# Collecting scikeras[tensorflow]
#   Downloading scikeras-0.12.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.10/dist-packages (from scikeras[tensorflow]) (23.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikeras[tensorflow]) (1.2.2)
# Collecting tensorflow<2.13.0,>=2.12.0 (from scikeras[tensorflow])
#   Downloading tensorflow-2.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (585.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.9/585.9 MB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras[tensorflow]) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras[tensorflow]) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras[tensorflow]) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras[tensorflow]) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (23.5.26)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow])
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (1.62.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (3.9.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (0.4.23)
# Collecting keras<2.13,>=2.12.0 (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow])
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 79.1 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (16.0.6)
# Collecting numpy>=1.17.3 (from scikit-learn>=1.0.0->scikeras[tensorflow])
#   Downloading numpy-1.24.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 76.3 MB/s eta 0:00:00
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (1.16.0)
# Collecting tensorboard<2.13,>=2.12 (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow])
#   Downloading tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 95.3 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.13,>=2.12.0 (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow])
#   Downloading tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 42.5 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (2.4.0)
# Collecting typing-extensions<4.6.0,>=3.6.6 (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow])
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (0.36.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (0.42.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (0.2.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (2.27.0)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow])
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (3.2.2)
# Installing collected packages: typing-extensions, tensorflow-estimator, numpy, keras, gast, google-auth-oauthlib, tensorboard, scikeras, tensorflow
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.10.0
#     Uninstalling typing_extensions-4.10.0:
#       Successfully uninstalled typing_extensions-4.10.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.15.0
#     Uninstalling tensorflow-estimator-2.15.0:
#       Successfully uninstalled tensorflow-estimator-2.15.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.4
#     Uninstalling gast-0.5.4:
#       Successfully uninstalled gast-0.5.4
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.0
#     Uninstalling google-auth-oauthlib-1.2.0:
#       Successfully uninstalled google-auth-oauthlib-1.2.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
#     Uninstalling tensorboard-2.15.2:
#       Successfully uninstalled tensorboard-2.15.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sqlalchemy 2.0.28 requires typing-extensions>=4.6.0, but you have typing-extensions 4.5.0 which is incompatible.
# pydantic 2.6.3 requires typing-extensions>=4.6.1, but you have typing-extensions 4.5.0 which is incompatible.
# pydantic-core 2.16.3 requires typing-extensions!=4.7.0,>=4.6.0, but you have typing-extensions 4.5.0 which is incompatible.
# Successfully installed gast-0.4.0 google-auth-oauthlib-1.0.0 keras-2.12.0 numpy-1.24.3 scikeras-0.12.0 tensorboard-2.12.3 tensorflow-2.12.1 tensorflow-estimator-2.12.0 typing-extensions-4.5.0

# %% [markdown]
# **Tuning of Hyperparamter : Batch size and Epochs**

# %%
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from scikeras.wrappers import KerasClassifier
from keras.optimizers import Adam

# %%
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim=8, kernel_initializer = 'uniform', activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    adam=Adam(learning_rate=0.01)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    return model

# %%
#Define the gridsearch cv
model = KerasClassifier(model = create_model,verbose = 0)
#Define the parameters
batch_size = [10,20,30]
epochs = [10,50,100]
#Make dict
param_grid = dict(batch_size = batch_size,epochs=epochs)

#Build and fit the GridSearch
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(), verbose = 10)
grid_result = grid.fit(x_scaled,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 1/5; 1/9] END .....batch_size=10, epochs=10;, score=0.773 total time=   2.4s
# [CV 2/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 2/5; 1/9] END .....batch_size=10, epochs=10;, score=0.682 total time=   2.1s
# [CV 3/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 3/5; 1/9] END .....batch_size=10, epochs=10;, score=0.779 total time=   4.0s
# [CV 4/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 4/5; 1/9] END .....batch_size=10, epochs=10;, score=0.797 total time=   3.7s
# [CV 5/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 5/5; 1/9] END .....batch_size=10, epochs=10;, score=0.791 total time=   1.5s
# [CV 1/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 1/5; 2/9] END .....batch_size=10, epochs=50;, score=0.747 total time=   6.0s
# [CV 2/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 2/5; 2/9] END .....batch_size=10, epochs=50;, score=0.688 total time=   4.9s
# [CV 3/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 3/5; 2/9] END .....batch_size=10, epochs=50;, score=0.766 total time=   5.9s
# [CV 4/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 4/5; 2/9] END .....batch_size=10, epochs=50;, score=0.843 total time=   5.9s
# [CV 5/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 5/5; 2/9] END .....batch_size=10, epochs=50;, score=0.752 total time=   5.1s
# [CV 1/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 1/5; 3/9] END ....batch_size=10, epochs=100;, score=0.721 total time=  11.2s
# [CV 2/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 2/5; 3/9] END ....batch_size=10, epochs=100;, score=0.682 total time=   9.9s
# [CV 3/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 3/5; 3/9] END ....batch_size=10, epochs=100;, score=0.766 total time=   9.9s
# [CV 4/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 4/5; 3/9] END ....batch_size=10, epochs=100;, score=0.804 total time=   9.3s
# [CV 5/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 5/5; 3/9] END ....batch_size=10, epochs=100;, score=0.765 total time=   9.7s
# [CV 1/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 1/5; 4/9] END .....batch_size=20, epochs=10;, score=0.760 total time=   1.4s
# [CV 2/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 2/5; 4/9] END .....batch_size=20, epochs=10;, score=0.682 total time=   1.2s
# [CV 3/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 3/5; 4/9] END .....batch_size=20, epochs=10;, score=0.786 total time=   2.4s
# [CV 4/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 4/5; 4/9] END .....batch_size=20, epochs=10;, score=0.745 total time=   1.4s
# [CV 5/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 5/5; 4/9] END .....batch_size=20, epochs=10;, score=0.784 total time=   1.3s
# [CV 1/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 1/5; 5/9] END .....batch_size=20, epochs=50;, score=0.760 total time=   3.5s
# [CV 2/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 2/5; 5/9] END .....batch_size=20, epochs=50;, score=0.714 total time=   3.3s
# [CV 3/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 3/5; 5/9] END .....batch_size=20, epochs=50;, score=0.766 total time=   4.4s
# [CV 4/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 4/5; 5/9] END .....batch_size=20, epochs=50;, score=0.863 total time=   3.6s
# [CV 5/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 5/5; 5/9] END .....batch_size=20, epochs=50;, score=0.758 total time=   3.3s
# [CV 1/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 1/5; 6/9] END ....batch_size=20, epochs=100;, score=0.747 total time=   6.0s
# [CV 2/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 2/5; 6/9] END ....batch_size=20, epochs=100;, score=0.701 total time=   5.9s
# [CV 3/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 3/5; 6/9] END ....batch_size=20, epochs=100;, score=0.779 total time=   5.8s
# [CV 4/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 4/5; 6/9] END ....batch_size=20, epochs=100;, score=0.837 total time=   6.1s
# [CV 5/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 5/5; 6/9] END ....batch_size=20, epochs=100;, score=0.752 total time=   5.0s
# [CV 1/5; 7/9] START batch_size=30, epochs=10....................................
# [CV 1/5; 7/9] END .....batch_size=30, epochs=10;, score=0.747 total time=   1.4s
# [CV 2/5; 7/9] START batch_size=30, epochs=10....................................
# [CV 2/5; 7/9] END .....batch_size=30, epochs=10;, score=0.695 total time=   1.7s
# [CV 3/5; 7/9] START batch_size=30, epochs=10....................................
# [CV 3/5; 7/9] END .....batch_size=30, epochs=10;, score=0.740 total time=   1.5s
# [CV 4/5; 7/9] START batch_size=30, epochs=10....................................
# [CV 4/5; 7/9] END .....batch_size=30, epochs=10;, score=0.797 total time=   1.3s
# [CV 5/5; 7/9] START batch_size=30, epochs=10....................................
# [CV 5/5; 7/9] END .....batch_size=30, epochs=10;, score=0.771 total time=   1.0s
# [CV 1/5; 8/9] START batch_size=30, epochs=50....................................
# [CV 1/5; 8/9] END .....batch_size=30, epochs=50;, score=0.766 total time=   3.3s
# [CV 2/5; 8/9] START batch_size=30, epochs=50....................................
# [CV 2/5; 8/9] END .....batch_size=30, epochs=50;, score=0.740 total time=   3.3s
# [CV 3/5; 8/9] START batch_size=30, epochs=50....................................
# [CV 3/5; 8/9] END .....batch_size=30, epochs=50;, score=0.773 total time=   3.2s
# [CV 4/5; 8/9] START batch_size=30, epochs=50....................................
# [CV 4/5; 8/9] END .....batch_size=30, epochs=50;, score=0.837 total time=   3.9s
# [CV 5/5; 8/9] START batch_size=30, epochs=50....................................
# [CV 5/5; 8/9] END .....batch_size=30, epochs=50;, score=0.758 total time=   2.3s
# [CV 1/5; 9/9] START batch_size=30, epochs=100...................................
# [CV 1/5; 9/9] END ....batch_size=30, epochs=100;, score=0.760 total time=   4.0s
# [CV 2/5; 9/9] START batch_size=30, epochs=100...................................
# [CV 2/5; 9/9] END ....batch_size=30, epochs=100;, score=0.708 total time=   4.8s
# [CV 3/5; 9/9] START batch_size=30, epochs=100...................................
# [CV 3/5; 9/9] END ....batch_size=30, epochs=100;, score=0.779 total time=   5.8s
# [CV 4/5; 9/9] START batch_size=30, epochs=100...................................
# [CV 4/5; 9/9] END ....batch_size=30, epochs=100;, score=0.837 total time=   5.9s
# [CV 5/5; 9/9] START batch_size=30, epochs=100...................................
# [CV 5/5; 9/9] END ....batch_size=30, epochs=100;, score=0.725 total time=   3.8s

# %%
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7747984042101689, using {'batch_size': 30, 'epochs': 50}
# 0.7644003055767762,0.042181493717526886 with: {'batch_size': 10, 'epochs': 10}
# 0.7592139886257534,0.04966337605058408 with: {'batch_size': 10, 'epochs': 50}
# 0.7474917239623122,0.042091544829330925 with: {'batch_size': 10, 'epochs': 100}
# 0.7513368983957218,0.037978066523752727 with: {'batch_size': 20, 'epochs': 10}
# 0.7722349545878957,0.04886748810056799 with: {'batch_size': 20, 'epochs': 50}
# 0.7631016042780749,0.04445313934252635 with: {'batch_size': 20, 'epochs': 100}
# 0.7500891265597147,0.03420074058629752 with: {'batch_size': 30, 'epochs': 10}
# 0.7747984042101689,0.03276176653867564 with: {'batch_size': 30, 'epochs': 50}
# 0.7617689500042442,0.045029324434933904 with: {'batch_size': 30, 'epochs': 100}

# %% [markdown]
# **Tuning of Hyperparameter : Learning rate and Dropout**

# %%
from keras.layers import Dropout

#Define the model

def create_model(learning_rate,dropout_rate):
  model = Sequential()
  model.add(Dense(8,input_dim = 8, kernal_initializer = 'normal',activation = 'relu'))
  model.add(Dropout(dropout_rate))
  model.add(Dense(4, input_dim = 8, kernal_initializer = 'normal',activation = 'relu'))
  model.add(Dropout(dropout_rate))
  model.add(Dense(1,activation = 'sigmoid'))

  adam = Adam(learning_rate = learning_rate)

  model = KerasClassifier(model = create_model, verbose = 0, batch_size = 40, epochs=10)

  learning_rate = [0.001,0.01,0.1]
  dropout_rate = [0.0,0.1,0.2]

  param_grids = dict(learning_rate = learning_rate,dropout_rate = dropout_rate)

  grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(x_scaled,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 1/5; 1/9] END .....batch_size=10, epochs=10;, score=0.773 total time=   2.3s
# [CV 2/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 2/5; 1/9] END .....batch_size=10, epochs=10;, score=0.714 total time=   2.4s
# [CV 3/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 3/5; 1/9] END .....batch_size=10, epochs=10;, score=0.760 total time=   2.3s
# [CV 4/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 4/5; 1/9] END .....batch_size=10, epochs=10;, score=0.856 total time=   3.6s
# [CV 5/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 5/5; 1/9] END .....batch_size=10, epochs=10;, score=0.732 total time=   2.0s
# [CV 1/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 1/5; 2/9] END .....batch_size=10, epochs=50;, score=0.721 total time=   5.9s
# [CV 2/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 2/5; 2/9] END .....batch_size=10, epochs=50;, score=0.740 total time=   6.1s
# [CV 3/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 3/5; 2/9] END .....batch_size=10, epochs=50;, score=0.773 total time=   5.0s
# [CV 4/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 4/5; 2/9] END .....batch_size=10, epochs=50;, score=0.830 total time=   5.6s
# [CV 5/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 5/5; 2/9] END .....batch_size=10, epochs=50;, score=0.765 total time=   5.6s
# [CV 1/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 1/5; 3/9] END ....batch_size=10, epochs=100;, score=0.773 total time=  11.0s
# [CV 2/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 2/5; 3/9] END ....batch_size=10, epochs=100;, score=0.714 total time=  11.8s
# [CV 3/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 3/5; 3/9] END ....batch_size=10, epochs=100;, score=0.753 total time=  10.4s
# [CV 4/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 4/5; 3/9] END ....batch_size=10, epochs=100;, score=0.824 total time=  11.3s
# [CV 5/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 5/5; 3/9] END ....batch_size=10, epochs=100;, score=0.739 total time=  10.5s
# [CV 1/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 1/5; 4/9] END .....batch_size=20, epochs=10;, score=0.766 total time=   1.4s
# [CV 2/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 2/5; 4/9] END .....batch_size=20, epochs=10;, score=0.708 total time=   1.4s
# [CV 3/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 3/5; 4/9] END .....batch_size=20, epochs=10;, score=0.747 total time=   2.0s
# [CV 4/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 4/5; 4/9] END .....batch_size=20, epochs=10;, score=0.784 total time=   1.7s
# [CV 5/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 5/5; 4/9] END .....batch_size=20, epochs=10;, score=0.752 total time=   1.4s
# [CV 1/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 1/5; 5/9] END .....batch_size=20, epochs=50;, score=0.649 total time=   3.0s
# [CV 2/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 2/5; 5/9] END .....batch_size=20, epochs=50;, score=0.740 total time=   3.0s
# [CV 3/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 3/5; 5/9] END .....batch_size=20, epochs=50;, score=0.792 total time=   3.4s
# [CV 4/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 4/5; 5/9] END .....batch_size=20, epochs=50;, score=0.843 total time=   6.1s
# [CV 5/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 5/5; 5/9] END .....batch_size=20, epochs=50;, score=0.778 total time=   3.0s
# [CV 1/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 1/5; 6/9] END ....batch_size=20, epochs=100;, score=0.747 total time=  11.0s
# [CV 2/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 2/5; 6/9] END ....batch_size=20, epochs=100;, score=0.701 total time=   5.3s
# [CV 3/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 3/5; 6/9] END ....batch_size=20, epochs=100;, score=0.760 total time=   6.1s
# [CV 4/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 4/5; 6/9] END ....batch_size=20, epochs=100;, score=0.843 total time=   5.2s
# [CV 5/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 5/5; 6/9] END ....batch_size=20, epochs=100;, score=0.771 total time=   6.2s
# [CV 1/5; 7/9] START batch_size=30, epochs=10....................................
# [CV 1/5; 7/9] END .....batch_size=30, epochs=10;, score=0.734 total time=   1.3s
# [CV 2/5; 7/9] START batch_size=30, epochs=10....................................
# [CV 2/5; 7/9] END .....batch_size=30, epochs=10;, score=0.695 total time=   1.7s
# [CV 3/5; 7/9] START batch_size=30, epochs=10....................................
# [CV 3/5; 7/9] END .....batch_size=30, epochs=10;, score=0.747 total time=   1.1s
# [CV 4/5; 7/9] START batch_size=30, epochs=10....................................
# [CV 4/5; 7/9] END .....batch_size=30, epochs=10;, score=0.765 total time=   1.4s
# [CV 5/5; 7/9] START batch_size=30, epochs=10....................................
# [CV 5/5; 7/9] END .....batch_size=30, epochs=10;, score=0.752 total time=   1.4s
# [CV 1/5; 8/9] START batch_size=30, epochs=50....................................
# [CV 1/5; 8/9] END .....batch_size=30, epochs=50;, score=0.760 total time=   3.3s
# [CV 2/5; 8/9] START batch_size=30, epochs=50....................................
# [CV 2/5; 8/9] END .....batch_size=30, epochs=50;, score=0.727 total time=   3.6s
# [CV 3/5; 8/9] START batch_size=30, epochs=50....................................
# [CV 3/5; 8/9] END .....batch_size=30, epochs=50;, score=0.760 total time=   3.3s
# [CV 4/5; 8/9] START batch_size=30, epochs=50....................................
# [CV 4/5; 8/9] END .....batch_size=30, epochs=50;, score=0.850 total time=   3.3s
# [CV 5/5; 8/9] START batch_size=30, epochs=50....................................
# [CV 5/5; 8/9] END .....batch_size=30, epochs=50;, score=0.739 total time=   3.4s
# [CV 1/5; 9/9] START batch_size=30, epochs=100...................................
# [CV 1/5; 9/9] END ....batch_size=30, epochs=100;, score=0.727 total time=   6.2s
# [CV 2/5; 9/9] START batch_size=30, epochs=100...................................
# [CV 2/5; 9/9] END ....batch_size=30, epochs=100;, score=0.708 total time=   4.0s
# [CV 3/5; 9/9] START batch_size=30, epochs=100...................................
# [CV 3/5; 9/9] END ....batch_size=30, epochs=100;, score=0.766 total time=   5.9s
# [CV 4/5; 9/9] START batch_size=30, epochs=100...................................
# [CV 4/5; 9/9] END ....batch_size=30, epochs=100;, score=0.863 total time=   3.9s
# [CV 5/5; 9/9] START batch_size=30, epochs=100...................................
# [CV 5/5; 9/9] END ....batch_size=30, epochs=100;, score=0.758 total time=   5.9s

# %%
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7669977081741788, using {'batch_size': 10, 'epochs': 10}
# 0.7669977081741788,0.04908308159397477 with: {'batch_size': 10, 'epochs': 10}
# 0.76570749511926,0.03703607234324099 with: {'batch_size': 10, 'epochs': 50}
# 0.7604702487055428,0.03685607179776607 with: {'batch_size': 10, 'epochs': 100}
# 0.7513453866395043,0.02540325034354071 with: {'batch_size': 20, 'epochs': 10}
# 0.7605466428995841,0.06464774856974916 with: {'batch_size': 20, 'epochs': 50}
# 0.7644342585519056,0.045959232058702365 with: {'batch_size': 20, 'epochs': 100}
# 0.7383329089211441,0.023911800062389903 with: {'batch_size': 30, 'epochs': 10}
# 0.7669977081741788,0.043190825182089866 with: {'batch_size': 30, 'epochs': 50}
# 0.764442746795688,0.05347298776707652 with: {'batch_size': 30, 'epochs': 100}

# %%
# !pip install keras==2.12.0
# Out:
# Requirement already satisfied: keras==2.12.0 in /usr/local/lib/python3.10/dist-packages (2.12.0)

# %%
from keras.wrappers.scikit_learn import KerasClassifier
